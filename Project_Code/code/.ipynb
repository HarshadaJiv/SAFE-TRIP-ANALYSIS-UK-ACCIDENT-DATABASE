# %% [markdown]
# # Load data

# %%
import pandas as pd

df = pd.read_csv("Road Safety Data - Casualties 2019.csv")
# Out:
# /Users/devarakondasantosh/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#        Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0       2019010128300                  1                   1               1
# 1       2019010128300                  1                   2               2
# 2       2019010128300                  1                   3               2
# 3       2019010152270                  1                   1               1
# 4       2019010155191                  2                   1               2
# ...               ...                ...                 ...             ...
# 153153  2019984106919                  1                   1               1
# 153154  2019984107019                  1                   1               1
# 153155  2019984107219                  2                   1               1
# 153156  2019984107419                  1                   1               3
# 153157  201998QC01004                  1                   1               1
#
# ...

# %%
df.head()
# Out:
#   Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0  2019010128300                  1                   1               1
# 1  2019010128300                  1                   2               2
# 2  2019010128300                  1                   3               2
# 3  2019010152270                  1                   1               1
# 4  2019010155191                  2                   1               2
#
#    Sex_of_Casualty  Age_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 0                1               58                     9                  3
# 1                2               -1                    -1                  3
# 2                2               -1                    -1                  3
# 3                2               24                     5                  3
# 4                2               21                     5                  3
#
#    Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153158 entries, 0 to 153157
# Data columns (total 16 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Accident_Index                      153158 non-null  object
#  1   Vehicle_Reference                   153158 non-null  int64
#  2   Casualty_Reference                  153158 non-null  int64
#  3   Casualty_Class                      153158 non-null  int64
#  4   Sex_of_Casualty                     153158 non-null  int64
#  5   Age_of_Casualty                     153158 non-null  int64
#  6   Age_Band_of_Casualty                153158 non-null  int64
#  7   Casualty_Severity                   153158 non-null  int64
#  8   Pedestrian_Location                 153158 non-null  int64
#  9   Pedestrian_Movement                 153158 non-null  int64
#  10  Car_Passenger                       153158 non-null  int64
# ...

# %%
df.describe()
# Out:
#        Vehicle_Reference  Casualty_Reference  Casualty_Class  Sex_of_Casualty  \
# count      153158.000000       153158.000000   153158.000000    153158.000000
# mean            1.464840            1.393933        1.493856         1.389754
# std             0.608019            2.820059        0.730922         0.516297
# min             1.000000            1.000000        1.000000        -1.000000
# 25%             1.000000            1.000000        1.000000         1.000000
# 50%             1.000000            1.000000        1.000000         1.000000
# 75%             2.000000            1.000000        2.000000         2.000000
# max            20.000000          991.000000        3.000000         2.000000
#
#        Age_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# count    153158.000000         153158.000000      153158.000000
# mean         36.932612              6.322347           2.807721
# std          19.686892              2.468329           0.422122
# ...

# %%
df.isnull().sum(axis = 0)
# Out:
# Accident_Index                        0
# Vehicle_Reference                     0
# Casualty_Reference                    0
# Casualty_Class                        0
# Sex_of_Casualty                       0
# Age_of_Casualty                       0
# Age_Band_of_Casualty                  0
# Casualty_Severity                     0
# Pedestrian_Location                   0
# Pedestrian_Movement                   0
# Car_Passenger                         0
# Bus_or_Coach_Passenger                0
# Pedestrian_Road_Maintenance_Worker    0
# Casualty_Type                         0
# Casualty_Home_Area_Type               0
# Casualty_IMD_Decile                   0
# dtype: int64

# %% [markdown]
# # Data clean up

# %%
df[df['Sex_of_Casualty']<0] #Dirty Data
# Out:
#        Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 383     2019010156414                  1                   2               2
# 1742    2019010159930                  1                   2               2
# 3745    2019010164961                  1                   3               2
# 3746    2019010164961                  1                   4               2
# 3747    2019010164961                  1                   5               2
# ...               ...                ...                 ...             ...
# 147990  2019950000422                  2                   2               1
# 148048  2019950000472                  2                   1               1
# 148221  2019950000635                  2                   2               1
# 148308  2019950000712                  1                   1               3
# 149055  2019950898057                  1                   1               1
#
# ...

# %%
df.drop(df[df['Sex_of_Casualty'] < 0].index, inplace=True)

# %%
df[df['Age_of_Casualty'] < 0] #Dirty Data
# Out:
#        Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 1       2019010128300                  1                   2               2
# 2       2019010128300                  1                   3               2
# 46      2019010155303                  1                   2               2
# 47      2019010155303                  1                   3               2
# 120     2019010155611                  1                   1               2
# ...               ...                ...                 ...             ...
# 149202  2019950913735                  2                   1               1
# 151397  201997GD00306                  2                   1               1
# 151777  201997GP02001                  1                   1               1
# 152368  201997ND00304                  2                   1               1
# 152468  201997QA00107                  2                   2               1
#
# ...

# %%
df.drop(df[df['Age_of_Casualty'] < 0].index, inplace=True)

# %%
df[df['Age_of_Casualty']>100] #Looks valid data only
# Out:
#       Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 54503  20191369I0701                  1                   1               3
# 90115  2019360838767                  1                   1               1
#
#        Sex_of_Casualty  Age_of_Casualty  Age_Band_of_Casualty  \
# 54503                1              102                    11
# 90115                2              101                    11
#
#        Casualty_Severity  Pedestrian_Location  Pedestrian_Movement  \
# 54503                  3                    5                    1
# 90115                  3                    0                    0
#
#        Car_Passenger  Bus_or_Coach_Passenger  \
# 54503              0                       0
# 90115              0                       0
#
#        Pedestrian_Road_Maintenance_Worker  Casualty_Type  \
# 54503                                   0              0
# 90115                                   0              9
#
# ...

# %%
df['Age_Band_of_Casualty'].unique()
# Out:
# array([ 9,  5, 10,  8,  4,  7,  6,  3,  1, 11,  2])

# %%
df[df['Age_Band_of_Casualty'] < 0] #Dirty Data

# df.drop(df[df['Age_Band_of_Casualty'] < 0].index, inplace=True)
# Out:
# Empty DataFrame
# Columns: [Accident_Index, Vehicle_Reference, Casualty_Reference, Casualty_Class, Sex_of_Casualty, Age_of_Casualty, Age_Band_of_Casualty, Casualty_Severity, Pedestrian_Location, Pedestrian_Movement, Car_Passenger, Bus_or_Coach_Passenger, Pedestrian_Road_Maintenance_Worker, Casualty_Type, Casualty_Home_Area_Type, Casualty_IMD_Decile]
# Index: []

# %%
df.describe()
# Out:
#        Vehicle_Reference  Casualty_Reference  Casualty_Class  Sex_of_Casualty  \
# count      149747.000000       149747.000000   149747.000000    149747.000000
# mean            1.467135            1.383754        1.487756         1.400963
# std             0.609050            2.824433        0.731447         0.490095
# min             1.000000            1.000000        1.000000         1.000000
# 25%             1.000000            1.000000        1.000000         1.000000
# 50%             1.000000            1.000000        1.000000         1.000000
# 75%             2.000000            1.000000        2.000000         2.000000
# max            20.000000          991.000000        3.000000         2.000000
#
#        Age_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# count    149747.000000         149747.000000      149747.000000
# mean         37.768116              6.482821           2.804811
# std          19.080139              2.243392           0.424842
# ...

# %% [markdown]
# # Data Correlation

# %%
corrMatrix = df.corr()
print (corrMatrix)
# Out:
#                                     Vehicle_Reference  Casualty_Reference  \
# Vehicle_Reference                            1.000000            0.070757
# Casualty_Reference                           0.070757            1.000000
# Casualty_Class                              -0.255547            0.045269
# Sex_of_Casualty                              0.015299            0.024205
# Age_of_Casualty                              0.036048           -0.027312
# Age_Band_of_Casualty                         0.047182           -0.035649
# Casualty_Severity                            0.083901            0.013160
# Pedestrian_Location                         -0.258049           -0.036075
# Pedestrian_Movement                         -0.222560           -0.028732
# Car_Passenger                                0.061254            0.141076
# Bus_or_Coach_Passenger                      -0.032154            0.059130
# Pedestrian_Road_Maintenance_Worker          -0.063979           -0.009894
# ...

# %%
import seaborn as sn
sn.heatmap(corrMatrix, annot=True)
plt.figure(figsize = (50,50))
plt.show()

# %%
# %matplotlib inline   

import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# Scatter Matrix
from pandas.plotting import scatter_matrix

# %matplotlib inline
# attributes =["Gender","Symptoms","Alcohol","HBsAg","HBeAg","HBcAb","HCVAb","Cirrhosis","Endemic","Smoking","Diabetes","Obesity","Hemochro","AHT","CRI","HIV","NASH","Varices","Spleno","PHT","PVT","Metastasis","Hallmark","Age","Grams_day","Packs_year","PS","Encephalopathy","Ascites","INR","AFP","Hemoglobin","MCV","Leucocytes","Platelets","Albumin","Total_Bil","ALT","AST","GGT","ALP","TP","Creatinine","Nodule","Major_Dim","Dir_Bil","Iron","Sat","Ferritin", "Class"]
scatter_matrix(df, figsize=(50,50))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1213d06d0>,
# ...
#       dtype=object)
